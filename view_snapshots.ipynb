# %%
JSON_PATH = "output/rugby_experiment/ar3_init.json"
N_COLUMNS = 24
VISIBLE_COLUMNS = 4

# %%
from pathlib import Path
import sys

ROOT = next(p for p in (Path.cwd(), *Path.cwd().parents)
            if (p / "viewer.html").is_file() and (p / "multidynnos_py").is_dir())
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from multidynnos_py.viewer import show_snapshots

show_snapshots(JSON_PATH, N_COLUMNS, VISIBLE_COLUMNS, viewer_path=ROOT / "viewer.html")
# Out:
#         <iframe
#             width="100%"
#             height="760"
#             src="about:blank"
#             frameborder="0"
#             allowfullscreen
#             title="Temporal graph snapshots" sandbox="allow-scripts" style="border:0;display:block" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot; data-viewer-state=&quot;loading&quot;&gt;
# &lt;head&gt;
# &lt;meta charset=&quot;utf-8&quot;&gt;
# &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1&quot;&gt;
# &lt;title&gt;Snapshot viewer&lt;/title&gt;
# &lt;style&gt;
# :root{color-scheme:light;font:14px/1.45 system-ui,-apple-system,BlinkMacSystemFont,&quot;Segoe UI&quot;,sans-serif;color:#263548;background:#f3f5f8}
# *{box-sizing:border-box}body{margin:0}button,input{font:inherit}button{color:inherit}
# main{padding:18px;max-width:2400px;margin:0 auto}
# .toolbar{position:sticky;top:0;z-index:2;padding:0 0 14px;background:#f3f5f8}
# ...
